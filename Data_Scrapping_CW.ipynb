# %% [markdown]
# <a href="https://colab.research.google.com/github/saksham060/HR-Analytics/blob/main/Data_Scrapping_CW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# %%
url="https://en.wikipedia.org/wiki/List_of_active_Indian_military_aircraft"
response=requests.get(url)

# %%
soup=BeautifulSoup(response.content,"html.parser")

# %%
table=soup.find("table",{"class":"wikitable"})
print(table)
# Out:
# <table class="wikitable">
# <tbody><tr>
# <th style="text-align:center; background:#acc;">Aircraft
# </th>
# <th style="text-align: center; background:#acc;">Origin
# </th>
# <th style="text-align: center; background:#acc;">Type
# </th>
# <th style="text-align:left; background:#acc;">Variant
# </th>
# <th style="text-align:center; background:#acc;">In service
# </th>
# <th style="text-align: center; background:#acc;">Notes
# </th></tr>
# <tr>
# <th colspan="6" style="align: center; background: lavender;"><a href="/wiki/Military_aircraft#Combat_aircraft" title="Military aircraft">Combat Aircraft</a>
# </th></tr>
# <tr>
# <td rowspan="2"><a href="/wiki/Dassault_Rafale" title="Dassault Rafale">Dassault Rafale</a>
# </td>
# <td rowspan="2"><a href="/wiki/France" title="France">France</a>
# </td>
# <td rowspan="2"><a href="/wiki/Multirole_combat_aircraft" title="Multirole combat aircraft">Multirole</a>
# </td>
# <td><a href="/wiki/Dassault_Rafale#Variants" title="Dassault Rafale">DH</a>
# ...

# %%
table.find_all("th")
# Out:
# [<th style="text-align:center; background:#acc;">Aircraft
#  </th>,
#  <th style="text-align: center; background:#acc;">Origin
#  </th>,
#  <th style="text-align: center; background:#acc;">Type
#  </th>,
#  <th style="text-align:left; background:#acc;">Variant
#  </th>,
#  <th style="text-align:center; background:#acc;">In service
#  </th>,
#  <th style="text-align: center; background:#acc;">Notes
#  </th>,
#  <th colspan="6" style="align: center; background: lavender;"><a href="/wiki/Military_aircraft#Combat_aircraft" title="Military aircraft">Combat Aircraft</a>
#  </th>,
#  <th colspan="6" style="align: center; background: lavender;"><a href="/wiki/Airborne_early_warning_and_control" title="Airborne early warning and control">AEW&amp;CS</a>
#  </th>,
#  <th colspan="6" style="align: center; background: lavender;"><a href="/wiki/Reconnaissance_aircraft" title="Reconnaissance aircraft">Reconnaissance</a>
#  </th>,
# ...

# %%
header=[]
for th in table.find_all("th"):
    header.append(th.text.strip())
print(header)
# Out:
# ['Aircraft', 'Origin', 'Type', 'Variant', 'In service', 'Notes', 'Combat Aircraft', 'AEW&CS', 'Reconnaissance', 'Tanker', 'Transport', 'Helicopters', 'Trainer Aircraft', 'UAV']

# %%
rows=[]
for tr in table.find_all("tr"):
    row=[]
    for td in tr.find_all("td"):
        row.append(td.text.strip())
    if row:
        rows.append(row)

# %%
rows[0]
# Out:
# ['Dassault Rafale', 'France', 'Multirole', 'DH', '8[1]', '']

# %%
import pandas as pd

# %%
df=pd.DataFrame(rows)
df.head()
# Out:
#                     0             1          2  \
# 0     Dassault Rafale        France  Multirole
# 1                  EH         28[1]
# 2           HAL Tejas         India  Multirole
# 3  Conversion trainer  Mk.1 Trainer    4[4][5]
# 4           Multirole         Mk.1A
#
#                                         3         4     5
# 0                                      DH      8[1]
# 1                                    None      None  None
# 2                                    Mk.1  31[2][3]
# 3  Used for training; 14 more on order[6]      None  None
# 4     73 on order, 97 more approved[6][7]      None  None

# %%
head_new=header[:6]
print(head_new)
# Out:
# ['Aircraft', 'Origin', 'Type', 'Variant', 'In service', 'Notes']

# %%
df.columns=head_new
df
# Out:
#                            Aircraft          Origin  \
# 0                   Dassault Rafale          France
# 1                                EH           28[1]
# 2                         HAL Tejas           India
# 3                Conversion trainer    Mk.1 Trainer
# 4                         Multirole           Mk.1A
# 5                   Sukhoi Su-30MKI          Russia
# 6                    Mikoyan MiG-29    Soviet Union
# 7                         Fulcrum B            7[1]
# 8              Dassault Mirage 2000          France
# 9                           -2000TH           10[1]
# 10                   SEPECAT Jaguar  United Kingdom
# 11                               IS           79[1]
# 12                               IM            8[1]
# 13          Mikoyan-Gurevich MiG-21    Soviet Union
# 14                     Embraer R-99          Brazil
# 15                      Beriev A-50    Soviet Union
# 16                       Boeing 707   United States
# ...

# %%
df.to_csv("aircraft.csv")
